# %%
import pandas as pd 
from simpledbf import Dbf5
import chardet

class PathDataSets:
    url = "C:/Users/carol/Downloads/solidarityEconomy/dataSets/"
    setores_91 = url + "setores_ceara_1991/"
    setores_00 = url + "setores_ceara_2000/"
    setores_10 = url + "setores_ceara_2010/"
    bairro = url + "logradouros_ce.csv"
    
file = PathDataSets.setores_91 + "desc_setores_91_messejana_finished.csv"

censo91 = pd.read_csv(file, encoding = "Windows-1252", sep = ";")

# %%
bairros_fortaleza = PathDataSets.bairro
bairros = pd.read_csv(bairros_fortaleza, encoding = "Windows-1252", sep = ";")
display(bairros)
# Out:
#                bairro                                         logradouro  \
# 0  conjunto_palmeiras  Rua Castro Alves, Rua Silvinha Téles, Rua Sidn...
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# 5                 NaN                                                NaN
# 6                 NaN                                                NaN
#
#                                        logradouros_t  Unnamed: 3  Unnamed: 4  \
# 0  RUA CASTRO ALVES, RUA SILVINHA TÉLES, RUA SIDN...         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2                                                NaN         NaN         NaN
# ...

# %%
bairro_selecionado = input("bairro ")
ultima_rua = input("qual a última rua da lista? EM UPPER  ")
# Out:
# bairro conjunto_palmeiras
# qual a última rua da lista? EM UPPER  RUA ISABELA MOREIRA

# %%
logradouros = bairros[bairros['bairro'] == bairro_selecionado]['logradouros_t']
logradouros = str(logradouros)
listLogradouros = logradouros.split(", ")
print(listLogradouros)
# Out:
# ['0    RUA CASTRO ALVES', 'RUA SILVINHA TÉLES', 'RUA SIDN...\nName: logradouros_t', 'dtype: object']

# %%
logradouros = []

for v11 in censo91.V11:
    for rua in logradouros:
        if rua in v11:
            listBoolLogradouros.append(True)
            break
        if rua == 'RUA ISABELA MOREIRA':
            listBoolLogradouros.append(False)

# %%
censo91["listLogradouro"] = logradouros
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 censo91["listLogradouro"] = logradouros
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
# ...

# %%
censo91[censo91["listLogradouro"] == True]
# Out:
#      V1   V2         V3  V4         V5  V6   V7  V8  V9  \
# 0    23  440  FORTALEZA  65  MESSEJANA   9   50   2   3
# 1    23  440  FORTALEZA  65  MESSEJANA   9   51   2   4
# 2    23  440  FORTALEZA  65  MESSEJANA   9   52   2   4
# 3    23  440  FORTALEZA  65  MESSEJANA   9   53   2   3
# 4    23  440  FORTALEZA  65  MESSEJANA   9   54   2   3
# ..   ..  ...        ...  ..        ...  ..  ...  ..  ..
# 212  23  440  FORTALEZA  65  MESSEJANA  11  216   2   2
# 213  23  440  FORTALEZA  65  MESSEJANA  11  217   2   3
# 214  23  440  FORTALEZA  65  MESSEJANA  11  218   2   3
# 215  23  440  FORTALEZA  65  MESSEJANA  11  219   2   5
# 216  23  440  FORTALEZA  65  MESSEJANA  11  220   2   5
#
#                                                    V11  listLogradouro  \
# 0    : DO PONTO INICIAL SEGUE PELA "AVENIDA JOSE LE...            True
# 1    : DO PONTO INICIAL SEGUE ATE A "RUA GENERAL CA...            True
# 2    : DO PONTO INICIAL SEGUE ATE A "RUA MANOEL MON...            True
# ...

# %%
nome = "|".join(logradouros)
print(censo91.V11.str.contains(nome))
censo91["logradouros"] = censo91.V11.str.contains(nome)
censo91.query("logradouros == True")
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 212    True
# 213    True
# 214    True
# 215    True
# 216    True
# Name: V11, Length: 217, dtype: bool
#      V1   V2         V3  V4         V5  V6   V7  V8  V9  \
# 0    23  440  FORTALEZA  65  MESSEJANA   9   50   2   3
# 1    23  440  FORTALEZA  65  MESSEJANA   9   51   2   4
# 2    23  440  FORTALEZA  65  MESSEJANA   9   52   2   4
# 3    23  440  FORTALEZA  65  MESSEJANA   9   53   2   3
# 4    23  440  FORTALEZA  65  MESSEJANA   9   54   2   3
# ..   ..  ...        ...  ..        ...  ..  ...  ..  ..
# 212  23  440  FORTALEZA  65  MESSEJANA  11  216   2   2
# 213  23  440  FORTALEZA  65  MESSEJANA  11  217   2   3
# 214  23  440  FORTALEZA  65  MESSEJANA  11  218   2   3
# 215  23  440  FORTALEZA  65  MESSEJANA  11  219   2   5
# 216  23  440  FORTALEZA  65  MESSEJANA  11  220   2   5
#
#                                                    V11  \
# ...
